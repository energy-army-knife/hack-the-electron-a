# %% [markdown]
# # Dataset Analysis

# %% [markdown]
# ## Meters

# %%
from collections import Counter
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

df_dataset = pd.read_csv('../resources/dataset_index.csv', sep=';', encoding="latin1")

print("Number of meters: {0}".format(df_dataset.shape[0]))
print("Variables: {0}".format(df_dataset.columns))
# Out:
# Number of meters: 219
# Variables: Index(['meter_id', 'tariff', 'n_phases', 'ctrct_pw'], dtype='object')

# %% [markdown]
# ### Tariff
# ###### The tariff variable has errors, some of the values have a whitespace in the end and others don't!

# %%
# %matplotlib inline
tariff_cleaned = [el.strip() for el in df_dataset.tariff]
tariff_counter = Counter(tariff_cleaned)
df = pd.DataFrame.from_dict(tariff_counter, orient='index')
tariff_counter_hist = df.plot(kind='bar')

# %% [markdown]
# ### Phase

# %%
df = pd.DataFrame.from_dict(Counter(df_dataset.n_phases), orient='index')
hist_n_phases = df.plot(kind='bar')

# %% [markdown]
# ### Contracted Power

# %%
plt.hist(df_dataset.ctrct_pw, bins=30)
plt.show()

# %% [markdown]
# ## Power

# %%
df_power = pd.read_csv('../resources/load_pwr.csv', sep=';', encoding="latin1")

# %%
df_power
# Out:
#        Unnamed: 0                 Time  meter_0  meter_1  meter_2  meter_3  \
# 0           65528  2016-10-01 00:15:00   1076.0    404.0     76.0    148.0
# 1           13752  2016-10-01 00:30:00   1064.0    440.0     56.0    116.0
# 2             126  2016-10-01 00:45:00   1036.0    484.0    136.0     20.0
# 3           50447  2016-10-01 01:00:00   1504.0    580.0     56.0     84.0
# 4           41489  2016-10-01 01:15:00   3236.0    488.0     68.0    252.0
# 5           32637  2016-10-01 01:30:00   2208.0    384.0    136.0    240.0
# 6           17889  2016-10-01 01:45:00   1028.0    456.0     40.0    116.0
# 7           53568  2016-10-01 02:00:00   1008.0    356.0     80.0    108.0
# 8           17197  2016-10-01 02:15:00   1004.0    504.0    120.0    256.0
# 9           54320  2016-10-01 02:30:00   2872.0    548.0     40.0    236.0
# 10          35363  2016-10-01 02:45:00   3224.0    444.0     92.0    144.0
# ...

# %% [markdown]
# ##### Some meters do not have power during a period of time (missing data or vacations?). Bellow is an example (meter_0), in this case specifically it seems a vacation period.

# %%
fig = matplotlib.pyplot.plot(range(df_power["meter_0"].shape[0]), df_power["meter_0"], ".")

# %%
array_month = df_power[(df_power['Time'] > "2016-11-01") & (df_power['Time'] < "2016-11-21")]
array_month.drop(array_month.columns[[0, 1]], axis=1, inplace=True)
# Out:
# /home/fmachado/anaconda3/envs/hack-the-electron-a/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
months = [str(el) for el in range(1,13)]

# %% [markdown]
# ### Evolution of power by month

# %%
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
mean_power_months = np.zeros((24, df_power.shape[1]-2))

n = 0
for year in ["2016", "2017", "2018"]:
    for month in months:
        date_upper = "{0}-{1}-01".format(year, month)
        date_lower = "{0}-{1}-31".format(year, month)
        filered_data = df_power[(df_power['Time'] > date_upper) & (df_power['Time'] < date_lower)]
        if filered_data.shape[0] > 1:
            filered_data.drop(filered_data.columns[[0, 1]], axis=1, inplace=True)
            mean_power_months[n,:] = filered_data.mean().to_numpy()
            n += 1

# %%
cmap = plt.get_cmap('gnuplot')
colors = [cmap(i) for i in np.linspace(0, 1, mean_power_months.shape[1])]

figure(num=None, figsize=(20, 10), facecolor='w', edgecolor='k')
for i, color in enumerate(colors, start=1):
    plt.plot(range(24), mean_power_months[:,i-1], color=color)
plt.show()

# %%
meters_id = df_power.columns[2:]

tarrif_names = list(tariff_counter.keys())

colors = [cmap(i) for i in np.linspace(0, 1, len(tarrif_names))]
colors_tarriff = {}
for i in range(len(tarrif_names)):
    colors_tarriff[tarrif_names[i]] = colors[i]
    
    
figure(num=None, figsize=(20, 10), facecolor='w', edgecolor='k')

for i in range(mean_power_months.shape[1]):
    meter_name = df_power.columns[2:][i]
    color_line = colors_tarriff[df_dataset.loc[df_dataset['meter_id'] == meter_name].iloc[0].tariff.strip()]
    plt.plot(range(24), mean_power_months[:,i], color=color_line)
plt.show()

# %%
contraced_power = list(set(df_dataset.ctrct_pw))

colors = [cmap(i) for i in np.linspace(0, 1, len(contraced_power))]
colors_contraced_power = {}
for i in range(len(contraced_power)):
    colors_contraced_power[contraced_power[i]] = colors[i]
    
figure(num=None, figsize=(20, 10), facecolor='w', edgecolor='k')

for i in range(mean_power_months.shape[1]):

    meter_name = df_power.columns[2:][i]
    color_line = colors_contraced_power[df_dataset.loc[df_dataset['meter_id'] == meter_name].iloc[0].ctrct_pw]
    plt.plot(range(24), mean_power_months[:,i], color=color_line)

plt.show()
